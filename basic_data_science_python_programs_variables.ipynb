# %% [markdown]
# # Variables
# The most basic program statement assigns a value to a variable with `=`.
# A variable initially is empty.
# Topics include:
# - Variable names
# - Assigning variables to basic data types
# - Reassigning variables
# - Operator assignment shortcuts
# - Multiple variable assignment
# - Assigned variables to data structure types
#
# <!--
# https://www.teach.cs.toronto.edu/~csc110y/fall/notes/
# https://www.teach.cs.toronto.edu/~csc110y/fall/notes/06-memory-model/04-python-memory-model-1.html
# https://www.teach.cs.toronto.edu/~csc148h/notes/python-recap/memory_model_part1.html
# https://www.teach.cs.toronto.edu/~csc148h/notes/python-recap/memory_model_part2.html
# -->

# %% [markdown]
# ## Variable names
# Variables have unique names.
# There are restrictions on variable names:
# - The characters in the name are limited to:
# | valid characters | examples |
# | - | - |
# | upper and lower case letters | `A`..`Z` and `a`..`z` |
# | numbers | `0`..`9` |
# | underscores | `_` |
# - They must not start with a number (and avoid starting with an underscore `_`, it's legal but could have special meaning to Python)
# - They are case-sensitive so that `Name` and `NAME` are different variables
# - They cannot be one of the built-in [reserved keywords](https://docs.python.org/3/reference/lexical_analysis.html#keywords) used for statements or operators
#
# Ideally, variable names should be a reminder of their purpose.
# When multiple words describe a variable's function,
# customary ways to connect the words are:
# - To use an underscore `_` to connect the words (*snake_case*), such as `variable_name`
# - Use *camelCase*, such as `variableName`
#
# There are some more notes on variable names:
# - It is customary to begin the name for a simple variable with a lowercase letter.
# - Sometimes a variable is used for a fixed value, like a conversion factor.
# A custom is to use a name with only uppercase and underscores for a constant.

# %%
KILOMETERS_TO_MILES = 0.6214
kilometers = 100
miles = kilometers * KILOMETERS_TO_MILES
print(miles)

# %% [markdown]
# __Exercise__. Create the name for variables that are:
# - the number of seconds in a minute
# - the number of minutes in an hour
#
# and compute the number of seconds in an hour.

# %% [markdown]
# ## Assigning variables to basic data types
# When assigning a variable to a basic data type value, `int`, `float`, `boolean`, or `string`,
# it is given a small place in memory to store a value.
# That variable is placed into the data state.
#
# <img src="https://raw.githubusercontent.com/kushnertodd/basic-data-science-python/main/docs/images/diagrams-variables-variables-2.jpg"
# alt="Assigning variables" width="200" height="auto">

# %%
# data state 0: ()
p = 42
print(p)
# data state 1: (p = 42)
q = 42.0
print(q)
# data state 2: (p = 42, q = 42.0)
r = True
print(r)
# data state 3: (p = 42, q = 42.0, r = True)
s = "42"
print(s)
# data state 4: (p = 42, q = 42.0, r = True, s = "42")

# %% [markdown]
# Variables are assigned to the value of *expressions*.
# An expression is a combination of variables, constants, operators, and functions that produce a value.
# Expressions follow the rules of standard mathematical statements.
# Any place a variable or function appears in an expression, its value is substituted.

# %%
# data state: ()
width = 2
# data state: (width = 2)
height = 21
# data state: (width = 2, height = 21)
area = width * height
# data state: (width = 2, height = 21, area = 42)
print(area)

# %% [markdown]
# __Exercise__. Compute `volume`, which is `area` * `depth`, for `depth = 2`, and print it.

# %% [markdown]
# A variable must be assigned a value and placed into the data state before it is used in an expression, else it gives an error. This commonly occurs when a variable name is misspelled.

# %%
# data state: ()
# print(p) -- this gives an error, p must be assigned a value before it is used
p = 42
# data state: (p = 42)
print(p)

# %% [markdown]
# __Exercise__. Assign `p` to a `float` or a `boolean`.

# %% [markdown]
# ## Reassigning variables
# After assigning a variable in a statement, the variable can be reassigned a new value of any type in a later statement.
# When a variable is assigned to new value, it simply replaces the old value in the storage space.
#
# <img src="https://raw.githubusercontent.com/kushnertodd/basic-data-science-python/main/docs/images/diagrams-variables-variables-3.jpg"
# alt="Reassigning variables" width="300"  height="auto">

# %%
# data state 0: ()
p = 42
print(p)
# data state 1: (p = 42)
p = 42.0
print(p)
# data state 2: (p = 42.0)
p = "42"
print(p)
# data state 3: (p = "42")
p = True
print(p)
# data state 4: (p = True)

# %% [markdown]
# ## Operator assignment shortcuts
# It is common to add, substract, multiply, or divide the variable with a value.

# %%
p = 40
p = p + 2
print(p)

# %%
q = 50
q = q - 8
print(q)

# %%
r = 21
r = r * 2
print(r)

# %%
s = 126
s = s / 3
print(s)

# %%
t = 128
t = t % 43
print(t)

# %%
u = 42
u = u ** 2
print(u)

# %% [markdown]
# __Exercise__. For `v = "42 "`, compute `v = v * 2` and print it.

# %% [markdown]
# Because this is so common, there are shortcut operators that are more concise.
# | shortcut | operation |
# | - | - |
# | += | addition assignment |
# | -= | substraction assignment |
# | *= | multiplication assignment |
# | /= | division assignment |
# | %=	| remainder |
# | \*\*= | exponentiation|

# %%
p = 40
p += 2
print(p)

# %%
q = 50
q -= 8
print(q)

# %%
r = 21
r *= 2
print(r)

# %%
s = 126
s /= 3
print(s)

# %%
t = 128
t %= 43
print(s)

# %%
u = 42
u **= 2
print(u)

# %% [markdown]
# __Exercise__. For `v = "42 "`, compute `v *= 2` and print it.

# %% [markdown]
# ## Multiple variable assignment
# As a convenience, more than one variable can be assigned in a single statement:
#
# *variable*`, `*variable*`, ... = `*value*`, `*value*`, ...`
#
# There must be as many variables as values.

# %%
p, q, r = 42, 42.0, "42"
print(p, q, r)
# Out:
# 42 42.0 42

# %% [markdown]
# A useful example is to swap the values of variables.

# %%
p, q = 42, 42.0
print(p, q)
p, q = q, r
print(p, q)
# Out:
# 42 42.0
# 42.0 42

# %% [markdown]
# ## Assigned variables to data structure types
# Assigning a variable to a data structure type: `list`s, `set`s, `dictionaries`s, is not as simple as with basic types.

# %% [markdown]
# ### Assigning variables to `lists`
# A list value can be arbitrarily large, so it cannot necessarily fit in a fixed storage space.
# Instead, a list is stored in a separate storage space and the variable is assigned a *reference* to that storage space.
#
# <img src="https://raw.githubusercontent.com/kushnertodd/basic-data-science-python/main/docs/images/diagrams-variables-list-1.jpg"
# alt="Assigning variables to lists" width="300"  height="auto">

# %% [markdown]
# ### Ressigning `list` item
# A list value can be arbitrarily large, so it cannot necessarily fit in a fixed storage space.
# Instead, a list is stored in a separate storage space and the variable is assigned a *reference* to that storage space.
#
# <img src="https://raw.githubusercontent.com/kushnertodd/basic-data-science-python/main/docs/images/diagrams-variables-list-2.jpg"
# alt="Assigning variables to lists" width="400"  height="auto">

# %% [markdown]
# ### Assigning variables to `dictionaries`
# A list value can be arbitrarily large, so it cannot necessarily fit in a fixed storage space.
# Instead, a list is stored in a separate storage space and the variable is assigned a *reference* to that storage space.
#
# <img src="https://raw.githubusercontent.com/kushnertodd/basic-data-science-python/main/docs/images/diagrams-variables-map-1.jpg"
# alt="Assigning variables to dictionaries" width="300"  height="auto">

# %% [markdown]
# ## Variable `is` operator

# %%
a = 1
b = 1
c = a
print(a is b)
print(a == b)
print(a is c)
print(a == c)
# Out:
# True
# True
# True
# True

# %%
a = 1000
b = 1000
c = a
print(a is b)
print(a == b)
print(a is c)
print(a == c)
# Out:
# False
# True
# True
# True

# %%
list_a = [1, 2, 3]
list_b = [1, 2, 3]
list_c = list_a  # c points to the same object as a

print(list_a == list_b)  # True  -> Their values are identical
print(list_a is list_b)  # False -> They are stored in different memory locations

print(list_a is list_c)  # True  -> 'list_c' is just a nickname for 'list_a'
# Out:
# True
# False
# True

# %% [markdown]
# Best Practice: When should you actually use is?
# The most common and "Pythonic" use case for the is operator is checking if a variable is None, True, or False. Because None is a singleton (only one None object ever exists in a running program), is is the safest and fastest way to check it. [4, 6, 7]
# ```
# # The right way to check for None
# if user_input is None:
#     print("No input provided")
# ```

# %% [markdown]
# ### Assigning variables to data structure types
# When a variable is assigned to a basic type value: `list`s, `set`s, `dictioaries`s, the new value is not as simple as with basic types.

# %% [markdown]
# ### Statements that modify lists
# The following are operations that modify lists assigned to variables.

# %%
# add a value to a list
a_list = ["string", 1.1, 42]
a_list.append(12)
print(a_list)

# %%
# add a list to the end of a list
a_list = ["string", 1.1, 42]
a_list.extend([12, "end"])
print(a_list)

# %%
# remove a value from a list
a_list = ["string", 1.1, 42]
a_list.remove(42)
print(a_list)

# %%
# add a value at a specific position
a_list = ["string", 1.1, 42]
a_list.insert(0, 3)
print(a_list)

# %%
# delete a value at a specific position
a_list = ["string", 1.1, 42]
del a_list[1]
print(a_list)

# %%
# reverse a list
a_list = ["string", 1.1, 42]
a_list.reverse()
print(a_list)

# %%
# sort a list
a_list = [3, 12.1, 42, 10]
a_list.sort()
print(a_list)

# %% [markdown]
# ### Statements that modify sets
# The following are operations that modify sets assigned to variables

# %%
# add a value to set
a_set = {"apple", "banana", "orange", "pear"}
a_set.add("grape")
print(a_set)

# %%
# remove a value from set
a_set = {"apple", "banana", "orange", "pear"}
a_set.remove("orange")
print(a_set)

# %%
# remove all values from a set
a_set = {"apple", "banana", "orange", "pear"}
a_set.clear()
print(a_set)

# %% [markdown]
# ### Statements that modify dictionaries
# The following are operations that modify dictionaries assigned to variables

# %%
# change a values in a dictionary
a_dict = {"leaf": "green", "sky": "blue", "apple": "red"}
a_dict["apple"] = "yellow"
print(a_dict)

# %%
# add a value to a dictionary
a_dict = {"leaf": "green", "sky": "blue", "apple": "red"}
a_dict["earth"] = "brown"
print(a_dict)

# %%
# remove a value from a dictionary
a_dict = {"leaf": "green", "sky": "blue", "apple": "red"}
del a_dict["sky"]
print(a_dict)

# %%
# combine two dictionaries
a_dict = {"leaf": "green", "sky": "blue", "apple": "red"}
another_dict = {"apple": "yellow", "sunset": "orange"}
a_dict.update(another_dict)
print(a_dict)

# %%
# remove all pairs in a dictionary
a_dict = {"leaf": "green", "sky": "blue", "apple": "red"}
a_dict.clear()
print(a_dict)
