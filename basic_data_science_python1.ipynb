# %% [markdown]
# # Python for Data Science
#
# This is an introduction to Python for Data Science projects. It will teach you the main elements you need to learn including:
# - Variables and primitive data types (integers, strings, floats)
# - Data collections like lists and dictionaries.
# - Statement flow control including if statements, for loops, and while loops
# - Writing custom functions and handling errors
