# %% [markdown]
# ## Dictionaries
# Dictionaries are a group where you look up a value with another value, a key, like looking up a word definition in a real dictionary. Dictionaries are formed with enclosing pairs of values of any type between braces {}. Dictionary values are accessed by key using square brackets.
# The dictionary `{'leaf': 'green', 'sky': 'blue', 'apple': 'red'}` can be visualized as:
# <table>
#     <tr>
#         <th style="text-align: center">key</th>
#         <th style="text-align: center">value</th>
#     </tr>
#     <tr style="background-color: transparent">
#         <td style="border: 1px solid black; width: 0.5in; text-align: center">leaf</td>
#         <td style="border: 1px solid black; width: 0.5in; text-align: center">green</td>
#     </tr>
#     <tr style="background-color: transparent">
#         <td style="border: 1px solid black; width: 0.5in; text-align: center">sky</td>
#         <td style="border: 1px solid black; width: 0.5in; text-align: center">blue</td>
#     </tr>
#     <tr style="background-color: transparent">
#         <td style="border: 1px solid black; width: 0.5in; text-align: center">apple</td>
#         <td style="border: 1px solid black; width: 0.5in; text-align: center">red</td>
#     </tr>
# </table>

# %%
# a sample dictionary
{'leaf': 'green', 'sky': 'blue', 'apple': 'red'}

# %%
# select a dictionary value
{'leaf': 'green', 'sky': 'blue', 'apple': 'red'}['leaf']

# %%
# count the dictionary pairs
len({'leaf': 'green', 'sky': 'blue', 'apple': 'red'})

# %%
#  detect if a key is in a dictionary
'leaf' in {'leaf': 'green', 'sky': 'blue', 'apple': 'red'}

# %%
#  detect if a key is not in a dictionary
'cloud' in {'leaf': 'green', 'sky': 'blue', 'apple': 'red'}

# %%
# list all the keys in a dictionary. The result of keys() is a special data structure, it needs to be converted to a list.
list({'leaf': 'green', 'sky': 'blue', 'apple': 'red'}.keys())

# %%
# list all the values in a dictionary. The result of values() is a special data structure, it needs to be converted to a list.
list({'leaf': 'green', 'sky': 'blue', 'apple': 'red'}.values())

# %% [markdown]
# Assume we have an account as a dictionary with account_no and balance keys:
# 	account = {
#         “account_no”: 38149,
#         “name”: “Best Buy”,
#         “balance”: 54.0
#      }
#
# Problem a. define a function that returns the account number from an account:
# 	def account_no(account)
# example:
# account = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 54.0 }
# 	print(account[“account_no”])
# 	prints:
# 38149
#
# answer:
#
#
# Problem b. define a function that returns the balance from an account:
# 	def account_balance(account)
# example:
# account = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 340.0 }
# 	print(account_balance({account))
# 	prints:
# 340.0
#
# answer:
#
#
# Problem c. define a function that prints an account:
# 	def account_print(account)
# example:
# 	account = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 172.0 }
# 	account_print(account)
# 	prints:
# {‘account_no’ = 38149, ‘name’: ‘Best Buy’, ‘balance’ = 172.0}
#
# answer:
#
#
# Problem d. define a function that changes the account number for an account:
# 	def account_change_account_no(account, account_no)
# example:
# 	account = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 172.0 }
# 	account_change_account_no(account, 54193)
# 	account_print(account)
# 	prints:
# account_no = 54193, balance = 172.0
#
# answer:
#
#
# Problem e. define a function that changes the balance for an account:
# 	def account_change_balance(account, balance)
# example:
# 	account = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 172.0 }
# 	account_change_balance(account, 178.0)
# 	account_print(account)
# 	prints:
# account_no = 38149, “name”: “Best Buy”, balance = 178.0
#
# answer:
#
#
# Problem f. define a function that credits the balance for an account:
# 	def account_deposit(account, amount)
# example:
# 	account = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 172.0 }
# 	account_deposit(account, 5.0)
# 	account_print(account)
# 	prints:
# account_no = 38149, “name”: “Best Buy”, balance = 177.0
#
# answer:
#
#
# Problem g. define a function that debits the balance for an account:
# 	def account_withdraw(account, amount)
# example:
# 	account = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 172.0 }
# 	account_withdraw(account, 11.0)
# 	account_print(account)
# 	prints:
# account_no = 38149, balance = 161.0
#
# Now work with a list of accounts. We define an account list as:
#
# account1 = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 284.0 }
# account2 = { “account_no”: 85172, “name”: “Office Max”, “balance”: 59.0 }
# account_list = [account1, account2]
#
#
# Problem h. define a function that finds an account in the account list by account_no. Return the account or None if not found:
# 	def account_find(account_list , account_no)
# example:
# account1 = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 284.0 }
# account2 = { “account_no”: 85172, “name”: “Office Max”, “balance”: 59.0 }
# account_list = [account1, account2]
# 	print(account_find(account_list, 38149))
# 	prints:
#  		{ “account_no”: 38149, “balance”: 284.0 }
# print(account_find(account_list, 99999))
# 	prints:
# No el no el we have no el
# answer:
#
#
# Problem i. define a function that removes an account in the account list by account_no. Return True if the account is deleted or None if not found:
# 	def account_remove(account_list, account_no)
# example:
# account1 = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 284.0 }
# account2 = { “account_no”: 85172, “name”: “Office Max”, “balance”: 59.0 }
# account_list = [account1, account2]
# 	print(account_remove((account_list, 38149))
# 	prints:
#  		True
# 	print(account_list)
# 	prints:
# [{“account_no”: 85172, “name”: “Office Max”, “balance”: 59.0}]
# account_list = [account1, account2]
# 	print(account_remove(account_list, 99999))
# 	prints:
# False
# 	account_print(account_list)
# 	prints:
# [ { “account_no”: 38149, “name”: “Best Buy”, “balance”: 284.0 }, { “account_no”: 85172, “name”: “Office Max”, “balance”: 59.0 }]
#
# answer:
#
#
# Problem j. define a function that sums the balances for all accounts in the account list.
# 	def account_balance_total(account_list)
# example:
# account1 = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 284.0 }
# account2 = { “account_no”: 85172, “name”: “Office Max”, “balance”: 59.0 }
# account_list = [account1, account2]
# 	print(account_balance_total(account_list))
# 	prints:
#  		343.0
#
# answer:
#
#
# Problem k. define a function that returns all account numbers for the accounts in the account list.
# 	def account_numbers(account_list)
# example:
# account1 = { “account_no”: 38149, “name”: “Best Buy”, “balance”: 284.0 }
# account2 = { “account_no”: 85172, “name”: “Office Max”, “balance”: 59.0 }
# account_list = [account1, account2]
# 	print(account_numbers(account_list))
# 	prints:
#  		[38149, 85172]
#
# answer:
#
#
# problem l. Explain why account_list_sort(account_list) is hard to implement.
#
# Because. It’s a big fuckin pain in the ass
