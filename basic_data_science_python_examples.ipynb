# %% [markdown]
# # Examples
# These are some data wrangling examples to put what we've learned so far to work.
#
# ## [Process a comma separated US States properties file](https://colab.research.google.com/github/kushnertodd/basic-data-science-python/blob/main/basic_data_science_python_examples_states.ipynb)
#
# Summarize data for US States over regions and for all states.
#
# ## [Clean a file of Audible data](https://colab.research.google.com/github/kushnertodd/basic-data-science-python/blob/main/basic_data_science_python_examples_audible.ipynb)
# A data cleaning exercise for a list of Audible audio books.
