# %% [markdown]
# # Python Resources
#
# There are quite a number of quality, free resources for learning Python.
#
# ## Official Python language website: `python.org`
# Python.org is the official website for the Python programming language
# This is the standard Python tutorial.
# - [The Python Tutorial](https://docs.python.org/3/tutorial/index.html)
#
# ## Python references
# These are reference websites that you will need later on for more advanced Python questions.
# - [Python Documentation](https://www.python.org/doc/)
# - [The Python Language Reference](https://docs.python.org/3/reference/)
# - [Python built-ins reference](https://docs.python.org/3/builtins/index.html#builtins-index)
# - [The Python standard library](https://docs.python.org/3/library/index.html#library-index)
#
# ## Free, online tutorials
# These are good quality, beginner-friendly online Python tutorials:
#
# - [w3schools](https://www.w3schools.com/python)
# - [Tutorialspoint](https://www.tutorialspoint.com/python)
# - [Google](https://developers.google.com/edu/python)
# - [Stanford](https://cs.stanford.edu/people/nick/py/)
# - [PYnative](https://pynative.com/get-started-with-python/)
#
# ## Free, online texts
# You should not miss these free online introductory Python texts:
#
# - [Automate the Boring Stuff with Python](https://automatetheboringstuff.com/)
# Publisher reference: [Automate the Boring Stuff with Python, 3rd Edition](https://nostarch.com/automate-boring-stuff-python-3rd-edition), Al Sweigart, No starch press
#
# - [Think Python](https://allendowney.github.io/ThinkPython/)
# Publisher reference: [Think Python, 3rd Edition](https://www.oreilly.com/library/view/think-python-3rd/9781098155421/), Allen B. Downey, O'Reilly
#
# ## Commercial texts
# These are highly recommended commercial texts:
# - [Programming Python, 4th Edition](https://www.oreilly.com/library/view/programming-python-4th/9781449398712/), Mark Lutz, O'Reilly
# - [Learning Python, 6th Edition](https://www.oreilly.com/library/view/learning-python-6th/9781098171292/), Mark Lutz, O'Reilly
# - [Python Crash Course, 3rd Edition](https://nostarch.com/python-crash-course-3rd-edition), Eric Matthes, No starch press
